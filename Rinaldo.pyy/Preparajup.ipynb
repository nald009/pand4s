# %% [markdown]
# pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_vendas_80_linhas.csv")

# %%
df
# Out:
#     id        data    categoria         produto  preco  quantidade  \
# 0    1  2024-01-29  Eletronicos            Fone    120           3
# 1    2  2024-01-04  Eletronicos          Webcam    200           4
# 2    3  2024-02-23  Eletronicos          Webcam    200           2
# 3    4  2024-02-05  Eletronicos           Mouse     80           4
# 4    5  2024-02-14  Eletronicos         Monitor    900           1
# ..  ..         ...          ...             ...    ...         ...
# 75  76  2024-03-16         Casa            Copo     15           2
# 76  77  2024-01-06    Alimentos          Feijao     20           1
# 77  78  2024-02-23  Eletronicos          Webcam    200           3
# 78  79  2024-03-07         Casa  Liquidificador    220           4
# 79  80  2024-02-05    Alimentos             Pao     12           2
#
#     desconto_percentual    cidade   canal pagamento  cliente_id
# 0                     0    Olinda  Online  Dinheiro        1047
# ...

# %%
regra_acima100 = df['preco'] >= 100
regra_cat = df['categoria'] == 'Eletronicos'
filtro_conjunto = regra_acima100 & regra_cat
tabela = df[filtro_conjunto]

# %%
tabela
# Out:
#     id        data    categoria  produto  preco  quantidade  \
# 0    1  2024-01-29  Eletronicos     Fone    120           3
# 1    2  2024-01-04  Eletronicos   Webcam    200           4
# 2    3  2024-02-23  Eletronicos   Webcam    200           2
# 4    5  2024-02-14  Eletronicos  Monitor    900           1
# 7    8  2024-03-22  Eletronicos  Monitor    900           3
# 15  16  2024-01-15  Eletronicos   Webcam    200           3
# 16  17  2024-03-05  Eletronicos  Teclado    150           5
# 19  20  2024-03-09  Eletronicos     Fone    120           4
# 28  29  2024-01-07  Eletronicos  Monitor    900           5
# 32  33  2024-03-05  Eletronicos     Fone    120           5
# 43  44  2024-01-19  Eletronicos  Teclado    150           5
# 50  51  2024-02-14  Eletronicos     Fone    120           5
# 51  52  2024-02-02  Eletronicos  Monitor    900           5
# 55  56  2024-02-25  Eletronicos  Teclado    150           3
# 66  67  2024-01-01  Eletronicos   Webcam    200           4
# ...
